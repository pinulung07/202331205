# %%
print('Muhamad Wino Jati Pinulung')
print('202331205')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Muhamad Wino Jati Pinulung
# 202331205

# %%
dataset = pd.read_csv('kaca.csv',sep=';')
dataset
# Out:
#     No Data Jenis Barang     Merk   Harga        Kelas
# 0         1       kramik  Vicenza  385500        Laris
# 1         2       kramik  Vicenza  538500        Laris
# 2         3       kramik  Vicenza  538500        Laris
# 3         4      plastik  Sunlife   18300        Laris
# 4         5      plastik  Sunlife   12500        Laris
# 5         6      plastik     Fori   27500        Laris
# 6         7         Kaca  Vicenza  520000        Laris
# 7         8         Kaca  Sunlife  179000  Tidak Laris
# 8         9       kramik  Sunlife  178000        Laris
# 9        10       kramik  Vicenza   44500        Laris
# 10       11         Kaca  Vicenza  600000        Laris
# 11       12         Kaca  Sunlife  285000  Tidak Laris
# 12       13         Kaca  Sunlife  329000  Tidak Laris
# 13       14         Kaca  Vicenza  415000        Laris
# 14       15       kramik  Vicenza  309000        Laris
# 15       16       kramik  Vicenza  865000        Laris
# 16       17       kramik     Fori  999000        Laris
# 17       18      plastik     Fori  339000        Laris
# 18       19      plastik    Fiori  289000        Laris
# 19       20      plastik    Fiori  559500        Laris

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   No Data       20 non-null     int64
#  1   Jenis Barang  20 non-null     object
#  2   Merk          20 non-null     object
#  3   Harga         20 non-null     int64
#  4   Kelas         20 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 932.0+ bytes

# %%
categorical_features = [feature for feature in dataset.columns if dataset[feature].dtypes == "O"]
dataset[categorical_features]
# Out:
#    Jenis Barang     Merk        Kelas
# 0        kramik  Vicenza        Laris
# 1        kramik  Vicenza        Laris
# 2        kramik  Vicenza        Laris
# 3       plastik  Sunlife        Laris
# 4       plastik  Sunlife        Laris
# 5       plastik     Fori        Laris
# 6          Kaca  Vicenza        Laris
# 7          Kaca  Sunlife  Tidak Laris
# 8        kramik  Sunlife        Laris
# 9        kramik  Vicenza        Laris
# 10         Kaca  Vicenza        Laris
# 11         Kaca  Sunlife  Tidak Laris
# 12         Kaca  Sunlife  Tidak Laris
# 13         Kaca  Vicenza        Laris
# 14       kramik  Vicenza        Laris
# 15       kramik  Vicenza        Laris
# 16       kramik     Fori        Laris
# 17      plastik     Fori        Laris
# 18      plastik    Fiori        Laris
# 19      plastik    Fiori        Laris

# %%
for i in categorical_features:
    print(dataset[i].unique())
# Out:
# ['kramik' 'plastik' 'Kaca']
# ['Vicenza' 'Sunlife' 'Fori' 'Fiori']
# ['Laris' 'Tidak Laris']

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

for feature in categorical_features:
    print(dataset[feature].unique())
    dataset[feature] = label_encoder.fit_transform(dataset[feature])
    print(dataset[feature].unique())
# Out:
# ['kramik' 'plastik' 'Kaca']
# [1 2 0]
# ['Vicenza' 'Sunlife' 'Fori' 'Fiori']
# [3 2 1 0]
# ['Laris' 'Tidak Laris']
# [0 1]

# %%
dataset
# Out:
#     No Data  Jenis Barang  Merk   Harga  Kelas
# 0         1             1     3  385500      0
# 1         2             1     3  538500      0
# 2         3             1     3  538500      0
# 3         4             2     2   18300      0
# 4         5             2     2   12500      0
# 5         6             2     1   27500      0
# 6         7             0     3  520000      0
# 7         8             0     2  179000      1
# 8         9             1     2  178000      0
# 9        10             1     3   44500      0
# 10       11             0     3  600000      0
# 11       12             0     2  285000      1
# 12       13             0     2  329000      1
# 13       14             0     3  415000      0
# 14       15             1     3  309000      0
# 15       16             1     3  865000      0
# 16       17             1     1  999000      0
# 17       18             2     1  339000      0
# 18       19             2     0  289000      0
# 19       20             2     0  559500      0

# %%
x = dataset.drop(['Kelas','No Data'], axis = 1)
y = dataset['Kelas']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=0)

# %%
from sklearn.naive_bayes import GaussiaNB
model = GaussiaNB()
model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from sklearn.naive_bayes import GaussiaNB
#       2 model = GaussiaNB()
#       3 model.fit(x_train, y_train)
#
# ImportError: cannot import name 'GaussiaNB' from 'sklearn.naive_bayes' (C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\naive_bayes.py)

# %%
pip install sklearn.naive_bayes
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement sklearn.naive_bayes (from versions: none)
# ERROR: No matching distribution found for sklearn.naive_bayes

# %%
pip install naive_bayes
# Out:
# Requirement already satisfied: naive_bayes in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (0.1.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: scikit-learn>=0.15.2 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from naive_bayes) (1.5.2)
# Requirement already satisfied: numpy>=1.9.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from naive_bayes) (2.1.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=0.15.2->naive_bayes) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=0.15.2->naive_bayes) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=0.15.2->naive_bayes) (3.5.0)

# %%
from sklearn.naive_bayes import GaussiaNB
model = GaussiaNB()
model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 from sklearn.naive_bayes import GaussiaNB
#       2 model = GaussiaNB()
#       3 model.fit(x_train, y_train)
#
# ImportError: cannot import name 'GaussiaNB' from 'sklearn.naive_bayes' (C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\naive_bayes.py)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model = GaussianNB()

# %%
model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred_train = model.predict(x_train)
y_pred_test = model.predict(x_test)

# %%
x_baru = np.array([[2,3,44500]])
y_pred_baru = model.predict(x_baru)
y_pred_baru
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array([0])

# %%
from sklearn.metrics import confusion_matrix, classification_report
print('evaluasi training')
print(confusion_matrix(y_train, y_pred_train))
print(classification_report(y_train, y_pred_train))

print('evaluasi testing')
print(confusion_matrix(y_test, y_pred_test))
print(classification_report(y_test, y_pred_test))
# Out:
# evaluasi training
# [[12  0]
#  [ 2  1]]
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.92        12
#            1       1.00      0.33      0.50         3
#
#     accuracy                           0.87        15
#    macro avg       0.93      0.67      0.71        15
# weighted avg       0.89      0.87      0.84        15
#
# evaluasi testing
# [[4 1]
#  [0 0]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89         5
#            1       0.00      0.00      0.00         0
#
#     accuracy                           0.80         5
#    macro avg       0.50      0.40      0.44         5
# weighted avg       1.00      0.80      0.89         5
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
